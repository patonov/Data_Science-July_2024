# %%
import numpy as np
import pandas as pd
import matplotlib as mpl

# %%
df = pd.read_csv("./input/accidents.csv")

# %%
df.columns
# Out:
# Index(['Miles from Home', '% of Accidents'], dtype='object')

# %%
df.head()
# Out:
#   Miles from Home  % of Accidents
# 0     less than 1              23
# 1          1 to 5              29
# 2         6 to 10              17
# 3        11 to 15               8
# 4        16 to 20               6

# %%
df.describe()
# Out:
#        % of Accidents
# count        6.000000
# mean        16.666667
# std          8.733079
# min          6.000000
# 25%         10.250000
# 50%         17.000000
# 75%         21.500000
# max         29.000000

# %%
df.shape
# Out:
# (6, 2)

# %%
df.columns = ["miles_from_home", "accident_rate"]

# %%
df.head
# Out:
# <bound method NDFrame.head of   miles_from_home  accident_rate
# 0     less than 1             23
# 1          1 to 5             29
# 2         6 to 10             17
# 3        11 to 15              8
# 4        16 to 20              6
# 5         over 20             17>

# %%
df.columns
# Out:
# Index(['miles_from_home', 'accident_rate'], dtype='object')

# %%
df
# Out:
#   miles_from_home  accident_rate
# 0     less than 1             23
# 1          1 to 5             29
# 2         6 to 10             17
# 3        11 to 15              8
# 4        16 to 20              6
# 5         over 20             17

# %%
df.accident_rate
# Out:
# 0    23
# 1    29
# 2    17
# 3     8
# 4     6
# 5    17
# Name: accident_rate, dtype: int64

# %%
df.dtypes
# Out:
# miles_from_home    object
# accident_rate       int64
# dtype: object

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of   miles_from_home  accident_rate
# 0     less than 1             23
# 1          1 to 5             29
# 2         6 to 10             17
# 3        11 to 15              8
# 4        16 to 20              6
# 5         over 20             17>

# %%
df
# Out:
#   miles_from_home  accident_rate
# 0     less than 1             23
# 1          1 to 5             29
# 2         6 to 10             17
# 3        11 to 15              8
# 4        16 to 20              6
# 5         over 20             17

# %%
df.index = ["a", "b", "c", "d", "e", "f"]

# %%
df
# Out:
#   miles_from_home  accident_rate
# a     less than 1             23
# b          1 to 5             29
# c         6 to 10             17
# d        11 to 15              8
# e        16 to 20              6
# f         over 20             17

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of   miles_from_home  accident_rate
# a     less than 1             23
# b          1 to 5             29
# c         6 to 10             17
# d        11 to 15              8
# e        16 to 20              6
# f         over 20             17>

# %%
df
# Out:
#   miles_from_home  accident_rate
# a     less than 1             23
# b          1 to 5             29
# c         6 to 10             17
# d        11 to 15              8
# e        16 to 20              6
# f         over 20             17

# %%
df.reset_index(drop = True)
# Out:
#   miles_from_home  accident_rate
# 0     less than 1             23
# 1          1 to 5             29
# 2         6 to 10             17
# 3        11 to 15              8
# 4        16 to 20              6
# 5         over 20             17

# %%
df
# Out:
#   miles_from_home  accident_rate
# a     less than 1             23
# b          1 to 5             29
# c         6 to 10             17
# d        11 to 15              8
# e        16 to 20              6
# f         over 20             17

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#   miles_from_home  accident_rate
# 0     less than 1             23
# 1          1 to 5             29
# 2         6 to 10             17
# 3        11 to 15              8
# 4        16 to 20              6
# 5         over 20             17

# %%
economic_df = pd.read_csv('https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/acf_p_ne/?format=SDMX-CSV&compressed=false')

# %%
economic_df
# Out:
#                 DATAFLOW        LAST UPDATE freq unit enterpr nace_r2 geo  \
# 0    ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC      HG     B-E  BE
# 1    ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC      HG     B-E  BG
# 2    ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC      HG     B-E  CY
# 3    ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC      HG     B-E  DE
# 4    ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC      HG     B-E  DK
# ..                   ...                ...  ...  ...     ...     ...  ..
# 475  ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC     YHG       M  NL
# 476  ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC     YHG       M  PL
# 477  ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC     YHG       M  SE
# 478  ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC     YHG       M  SK
# 479  ESTAT:ACF_P_NE(1.0)  23/03/17 23:00:00    A   PC     YHG       M  UK
#
#      TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0           2010       57.8       NaN
# ...

# %%
economic_df.dtypes
# Out:
# DATAFLOW        object
# LAST UPDATE     object
# freq            object
# unit            object
# enterpr         object
# nace_r2         object
# geo             object
# TIME_PERIOD      int64
# OBS_VALUE      float64
# OBS_FLAG       float64
# dtype: object

# %%
economic_df.describe().T
# Out:
#              count       mean        std     min       25%     50%       75%  \
# TIME_PERIOD  480.0  2010.0000   0.000000  2010.0  2010.000  2010.0  2010.000
# OBS_VALUE    480.0    48.8275  20.028317     0.0    38.075    50.0    64.025
# OBS_FLAG       0.0        NaN        NaN     NaN       NaN     NaN       NaN
#
#                 max
# TIME_PERIOD  2010.0
# OBS_VALUE     100.0
# OBS_FLAG        NaN

# %%
import pandas as pd
import xlrd as xr

# %%
new_df = pd.read_excel("./input/green_tripdata_2015-09.xls")

# %%
new_df
# Out:
#        VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0             2  2015-09-01 00:02:34   2015-09-01 00:02:38                  N
# 1             2  2015-09-01 00:04:20   2015-09-01 00:04:24                  N
# 2             2  2015-09-01 00:01:50   2015-09-01 00:04:24                  N
# 3             2  2015-09-01 00:02:36   2015-09-01 00:06:42                  N
# 4             2  2015-09-01 00:00:14   2015-09-01 00:04:20                  N
# ...         ...                  ...                   ...                ...
# 65530         2  2015-09-02 16:51:59   2015-09-02 17:04:00                  N
# 65531         2  2015-09-02 16:53:51   2015-09-02 17:04:32                  N
# 65532         2  2015-09-02 16:57:21   2015-09-02 17:05:03                  N
# 65533         2  2015-09-02 16:51:42   2015-09-02 17:05:28                  N
# 65534         2  2015-09-02 16:40:36   2015-09-02 16:48:20                  N
#
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.hist(new_df.Fare_amount, bins = 50)
plt.show()

# %%
plt.hist(new_df.Fare_amount[new_df.Fare_amount > 0], bins = 50)
plt.show()

# %%
new_df.Fare_amount[new_df.Fare_amount > 0].skew()
# Out:
# 7.01369599688203

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mssql+pymssql://DESKTOP-79AOHR2/SoftUni")

# %%
pd.read_sql("SELECT * FROM Employees", engine)
# Out:
#      EmployeeID FirstName    LastName MiddleName  \
# 0             1       Guy     Gilbert          R
# 1             2     Kevin       Brown          F
# 2             3   Roberto  Tamburello       None
# 3             4       Rob     Walters       None
# 4             5   Thierry      D'Hers          B
# ..          ...       ...         ...        ...
# 288         289    Rachel      Valdez          B
# 289         290      Lynn    Tsoflias
# 290         291   Svetlin       Nakov     Ivanov
# 291         292    Martin       Kulov       None
# 292         293    George     Denchev       None
#
#                                          JobTitle  DepartmentID  ManagerID  \
# 0                           Production Technician             7       16.0
# 1                             Marketing Assistant             4        6.0
# 2                             Engineering Manager             1       12.0
# 3                            Senior Tool Designer             2        3.0
# ...
