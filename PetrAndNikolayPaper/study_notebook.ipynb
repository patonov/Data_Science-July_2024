# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("CEE_panel.xlsx")

# %%
df.info
# Out:
# <bound method DataFrame.info of       country  year     VAT      TPI  CapT     PIT     CIT  TotalRev     EASC  \
# 0    Bulgaria  1995   695.1   1211.6  19.3   624.6    96.7    3810.0    878.3
# 1    Bulgaria  1996   579.8    878.7  11.7   474.2    87.2    2815.7    607.6
# 2    Bulgaria  1997     568    953.6   7.4   540.6   672.3    3348.2    699.2
# 3    Bulgaria  1998   960.5   1682.1  14.1   768.3   558.3    4741.3    964.5
# 4    Bulgaria  1999   965.8   1668.3  14.9   788.8   513.8    5328.1   1083.6
# ..        ...   ...     ...      ...   ...     ...     ...       ...      ...
# 325  Slovakia  2020  6820.2  11252.8     0    3500  2799.7   36977.2   8649.6
# 326  Slovakia  2021  7494.1  12056.5     0  3759.7  3632.6   40504.6   9141.0
# 327  Slovakia  2022  8555.7  13220.9     0  4163.9  4533.8   45653.2   9663.9
# 328  Slovakia  2023    9733  14854.6     0  4685.4  4490.8   53053.6  10718.6
# 329  Slovakia  2024  9914.7  15147.2     0  4812.7  5082.1   54649.3  12069.2
#
#          NSC       GDP     GFCF   Income
# 0      985.2   14512.8   2419.1   4321.9
# 1      667.0    9829.8    437.6   2957.2
# 2      771.5   10064.7    974.4   3156.6
# 3     1081.8   13437.6   1961.1   4689.2
# 4     1265.1   12804.4   2081.4   4780.2
# ..       ...       ...      ...      ...
# 325  14544.1   94320.6  18657.5  41052.7
# 326  15683.4  101891.6  19968.9  43455.9
# 327  16595.5  109959.8  23025.7  46720.2
# 328  18945.7  123538.7  26111.2  51616.1
# 329  20964.7  130207.5  26586.3  55404.2
#
# [330 rows x 13 columns]>

# %%
df.dtypes
# Out:
# country      object
# year          int64
# VAT         float64
# TPI         float64
# CapT         object
# PIT          object
# CIT          object
# TotalRev    float64
# EASC        float64
# NSC         float64
# GDP         float64
# GFCF        float64
# Income      float64
# dtype: object

# %%
df["VAT"] = (df["VAT"].replace("na", "")).astype(float)

# %%
regression = linear_model.LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
X = df[["TotalRev", "EASC"]]
y = df["GDP"]

# %%
regression.get_params(deep=True)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
regression.score(X, y)
# Out:
# 0.9923557973842887

# %%
regression.coef_
# Out:
# array([ 2.58816376, -0.93607488])
